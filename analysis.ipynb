# %%
import pandas as pd

# %%
train_df = pd.read_csv('data/train.csv')
test_df = pd.read_csv('data/test.csv')
solution_format = pd.read_csv("data/solution_format.csv")

# %%
solution_format.head()
# Out:
#     obs salary_category
# 0  1281             Low
# 1  1282            High
# 2  1283             Low
# 3  1284             Low
# 4  1285            High

# %%
train_df.head()
# Out:
#    obs    job_title job_posted_date salary_category job_state feature_1  \
# 0    1       Others         2024/07            High        NY         A
# 1    2  Job_Title_1         2024/07             Low        CA         A
# 2    3       Others         2024/07             Low        CA         A
# 3    4       Others         2024/07             Low        CA         A
# 4    5       Others         2024/07             Low        CA         A
#
#    feature_2  feature_3  feature_4  feature_5  ...  job_desc_291  \
# 0     0.6429      False      False       True  ...     -0.362079
# 1     0.4678      False      False      False  ...     -0.300989
# 2     0.4610      False      False      False  ...      0.000000
# 3     0.5064      False      False      False  ...      0.000000
# 4     0.4640      False      False      False  ...     -0.406159
#
#    job_desc_292  job_desc_293  job_desc_294  job_desc_295  job_desc_296  \
# 0     -0.499308     -0.367894     -0.214881      0.014870     -0.271177
# 1     -0.415411     -0.341824     -0.319064      0.042322     -0.124755
# 2      0.000000      0.000000      0.000000      0.000000      0.000000
# 3      0.000000      0.000000      0.000000      0.000000      0.000000
# 4     -0.654657     -0.074398     -0.464479      0.081037     -0.136992
#
#    job_desc_297  job_desc_298  job_desc_299  job_desc_300
# 0     -0.113347     -0.587955     -0.919095     -0.207340
# 1      0.023489     -0.893224     -0.823024      0.112364
# 2      0.000000      0.000000      0.000000      0.000000
# 3      0.000000      0.000000      0.000000      0.000000
# 4     -0.276270     -0.696853     -0.601466      0.089939
#
# [5 rows x 317 columns]

# %%
test_df.head()
# Out:
#     obs    job_title job_posted_date job_state feature_1  feature_2  \
# 0  1281       Others         2024/06        CA         A     0.6473
# 1  1282       Others         2024/08        NY         A     0.4238
# 2  1283       Others         2023/01        CA         A     0.6219
# 3  1284  Job_Title_5         2024/06        NY         A     0.6704
# 4  1285       Others         2024/05        CA         A     0.7310
#
#    feature_3  feature_4  feature_5  feature_6  ...  job_desc_291  \
# 0      False      False       True       True  ...     -0.054078
# 1       True      False      False      False  ...     -0.868718
# 2       True      False      False       True  ...     -0.416109
# 3      False      False      False       True  ...     -0.297560
# 4      False      False      False       True  ...     -0.176458
#
#    job_desc_292  job_desc_293  job_desc_294  job_desc_295  job_desc_296  \
# 0     -0.573635     -0.306883     -0.325092      0.089463     -0.353476
# 1     -0.337967     -0.179036     -0.717763      0.404843      0.032468
# 2     -0.619822     -0.493653     -0.347556      0.071679     -0.331212
# 3     -0.481448     -0.497642     -0.254823      0.047404     -0.362739
# 4     -0.726473     -0.323976     -0.145825     -0.046866     -0.229873
#
#    job_desc_297  job_desc_298  job_desc_299  job_desc_300
# 0     -0.159314     -0.667958     -0.702116     -0.206267
# 1     -0.190448     -1.261702     -0.505897      0.082080
# 2     -0.381348     -0.506540     -0.773561     -0.105221
# 3     -0.102704     -0.491272     -0.808156     -0.048326
# 4     -0.568318     -0.614605     -0.770506      0.142140
#
# [5 rows x 316 columns]

# %%
train_df.salary_category.value_counts()
# Out:
# salary_category
# High      501
# Low       419
# Medium    360
# Name: count, dtype: int64

# %%
train_df.job_state.value_counts()
# Out:
# job_state
# CA    559
# NY    501
# TX     25
# NJ     20
# VA     19
# IL     15
# MA     14
# WA     13
# GA     10
# DC      8
# CO      8
# MN      7
# FL      6
# NC      5
# MD      5
# OR      4
# OH      4
# PA      4
# SC      3
# NM      2
# OK      2
# CT      2
# MI      2
# IN      2
# AZ      2
# AK      1
# UT      1
# SD      1
# TN      1
# AR      1
# LA      1
# KY      1
# NV      1
# IA      1
# MO      1
# AL      1
# Name: count, dtype: int64

# %%
list(train_df.columns)
# Out:
# ['obs',
#  'job_title',
#  'job_posted_date',
#  'salary_category',
#  'job_state',
#  'feature_1',
#  'feature_2',
#  'feature_3',
#  'feature_4',
#  'feature_5',
#  'feature_6',
#  'feature_7',
#  'feature_8',
#  'feature_9',
#  'feature_10',
#  'feature_11',
#  'feature_12',
#  'job_desc_001',
#  'job_desc_002',
#  'job_desc_003',
#  'job_desc_004',
#  'job_desc_005',
#  'job_desc_006',
#  'job_desc_007',
#  'job_desc_008',
#  'job_desc_009',
#  'job_desc_010',
#  'job_desc_011',
#  'job_desc_012',
#  'job_desc_013',
#  'job_desc_014',
#  'job_desc_015',
#  'job_desc_016',
#  'job_desc_017',
#  'job_desc_018',
#  'job_desc_019',
#  'job_desc_020',
#  'job_desc_021',
#  'job_desc_022',
#  'job_desc_023',
#  'job_desc_024',
#  'job_desc_025',
#  'job_desc_026',
#  'job_desc_027',
#  'job_desc_028',
#  'job_desc_029',
#  'job_desc_030',
#  'job_desc_031',
#  'job_desc_032',
#  'job_desc_033',
#  'job_desc_034',
#  'job_desc_035',
#  'job_desc_036',
#  'job_desc_037',
#  'job_desc_038',
#  'job_desc_039',
#  'job_desc_040',
#  'job_desc_041',
#  'job_desc_042',
#  'job_desc_043',
#  'job_desc_044',
#  'job_desc_045',
#  'job_desc_046',
#  'job_desc_047',
#  'job_desc_048',
#  'job_desc_049',
#  'job_desc_050',
#  'job_desc_051',
#  'job_desc_052',
#  'job_desc_053',
#  'job_desc_054',
#  'job_desc_055',
#  'job_desc_056',
#  'job_desc_057',
#  'job_desc_058',
#  'job_desc_059',
#  'job_desc_060',
#  'job_desc_061',
#  'job_desc_062',
#  'job_desc_063',
#  'job_desc_064',
#  'job_desc_065',
#  'job_desc_066',
#  'job_desc_067',
#  'job_desc_068',
#  'job_desc_069',
#  'job_desc_070',
#  'job_desc_071',
#  'job_desc_072',
#  'job_desc_073',
#  'job_desc_074',
#  'job_desc_075',
#  'job_desc_076',
#  'job_desc_077',
#  'job_desc_078',
#  'job_desc_079',
#  'job_desc_080',
#  'job_desc_081',
#  'job_desc_082',
#  'job_desc_083',
#  'job_desc_084',
#  'job_desc_085',
#  'job_desc_086',
#  'job_desc_087',
#  'job_desc_088',
#  'job_desc_089',
#  'job_desc_090',
#  'job_desc_091',
#  'job_desc_092',
#  'job_desc_093',
#  'job_desc_094',
#  'job_desc_095',
#  'job_desc_096',
#  'job_desc_097',
#  'job_desc_098',
#  'job_desc_099',
#  'job_desc_100',
#  'job_desc_101',
#  'job_desc_102',
#  'job_desc_103',
#  'job_desc_104',
#  'job_desc_105',
#  'job_desc_106',
#  'job_desc_107',
#  'job_desc_108',
#  'job_desc_109',
#  'job_desc_110',
#  'job_desc_111',
#  'job_desc_112',
#  'job_desc_113',
#  'job_desc_114',
#  'job_desc_115',
#  'job_desc_116',
#  'job_desc_117',
#  'job_desc_118',
#  'job_desc_119',
#  'job_desc_120',
#  'job_desc_121',
#  'job_desc_122',
#  'job_desc_123',
#  'job_desc_124',
#  'job_desc_125',
#  'job_desc_126',
#  'job_desc_127',
#  'job_desc_128',
#  'job_desc_129',
#  'job_desc_130',
#  'job_desc_131',
#  'job_desc_132',
#  'job_desc_133',
#  'job_desc_134',
#  'job_desc_135',
#  'job_desc_136',
#  'job_desc_137',
#  'job_desc_138',
#  'job_desc_139',
#  'job_desc_140',
#  'job_desc_141',
#  'job_desc_142',
#  'job_desc_143',
#  'job_desc_144',
#  'job_desc_145',
#  'job_desc_146',
#  'job_desc_147',
#  'job_desc_148',
#  'job_desc_149',
#  'job_desc_150',
#  'job_desc_151',
#  'job_desc_152',
#  'job_desc_153',
#  'job_desc_154',
#  'job_desc_155',
#  'job_desc_156',
#  'job_desc_157',
#  'job_desc_158',
#  'job_desc_159',
#  'job_desc_160',
#  'job_desc_161',
#  'job_desc_162',
#  'job_desc_163',
#  'job_desc_164',
#  'job_desc_165',
#  'job_desc_166',
#  'job_desc_167',
#  'job_desc_168',
#  'job_desc_169',
#  'job_desc_170',
#  'job_desc_171',
#  'job_desc_172',
#  'job_desc_173',
#  'job_desc_174',
#  'job_desc_175',
#  'job_desc_176',
#  'job_desc_177',
#  'job_desc_178',
#  'job_desc_179',
#  'job_desc_180',
#  'job_desc_181',
#  'job_desc_182',
#  'job_desc_183',
#  'job_desc_184',
#  'job_desc_185',
#  'job_desc_186',
#  'job_desc_187',
#  'job_desc_188',
#  'job_desc_189',
#  'job_desc_190',
#  'job_desc_191',
#  'job_desc_192',
#  'job_desc_193',
#  'job_desc_194',
#  'job_desc_195',
#  'job_desc_196',
#  'job_desc_197',
#  'job_desc_198',
#  'job_desc_199',
#  'job_desc_200',
#  'job_desc_201',
#  'job_desc_202',
#  'job_desc_203',
#  'job_desc_204',
#  'job_desc_205',
#  'job_desc_206',
#  'job_desc_207',
#  'job_desc_208',
#  'job_desc_209',
#  'job_desc_210',
#  'job_desc_211',
#  'job_desc_212',
#  'job_desc_213',
#  'job_desc_214',
#  'job_desc_215',
#  'job_desc_216',
#  'job_desc_217',
#  'job_desc_218',
#  'job_desc_219',
#  'job_desc_220',
#  'job_desc_221',
#  'job_desc_222',
#  'job_desc_223',
#  'job_desc_224',
#  'job_desc_225',
#  'job_desc_226',
#  'job_desc_227',
#  'job_desc_228',
#  'job_desc_229',
#  'job_desc_230',
#  'job_desc_231',
#  'job_desc_232',
#  'job_desc_233',
#  'job_desc_234',
#  'job_desc_235',
#  'job_desc_236',
#  'job_desc_237',
#  'job_desc_238',
#  'job_desc_239',
#  'job_desc_240',
#  'job_desc_241',
#  'job_desc_242',
#  'job_desc_243',
#  'job_desc_244',
#  'job_desc_245',
#  'job_desc_246',
#  'job_desc_247',
#  'job_desc_248',
#  'job_desc_249',
#  'job_desc_250',
#  'job_desc_251',
#  'job_desc_252',
#  'job_desc_253',
#  'job_desc_254',
#  'job_desc_255',
#  'job_desc_256',
#  'job_desc_257',
#  'job_desc_258',
#  'job_desc_259',
#  'job_desc_260',
#  'job_desc_261',
#  'job_desc_262',
#  'job_desc_263',
#  'job_desc_264',
#  'job_desc_265',
#  'job_desc_266',
#  'job_desc_267',
#  'job_desc_268',
#  'job_desc_269',
#  'job_desc_270',
#  'job_desc_271',
#  'job_desc_272',
#  'job_desc_273',
#  'job_desc_274',
#  'job_desc_275',
#  'job_desc_276',
#  'job_desc_277',
#  'job_desc_278',
#  'job_desc_279',
#  'job_desc_280',
#  'job_desc_281',
#  'job_desc_282',
#  'job_desc_283',
#  'job_desc_284',
#  'job_desc_285',
#  'job_desc_286',
#  'job_desc_287',
#  'job_desc_288',
#  'job_desc_289',
#  'job_desc_290',
#  'job_desc_291',
#  'job_desc_292',
#  'job_desc_293',
#  'job_desc_294',
#  'job_desc_295',
#  'job_desc_296',
#  'job_desc_297',
#  'job_desc_298',
#  'job_desc_299',
#  'job_desc_300']

# %%
list(test_df.columns)
# Out:
# ['obs',
#  'job_title',
#  'job_posted_date',
#  'job_state',
#  'feature_1',
#  'feature_2',
#  'feature_3',
#  'feature_4',
#  'feature_5',
#  'feature_6',
#  'feature_7',
#  'feature_8',
#  'feature_9',
#  'feature_10',
#  'feature_11',
#  'feature_12',
#  'job_desc_001',
#  'job_desc_002',
#  'job_desc_003',
#  'job_desc_004',
#  'job_desc_005',
#  'job_desc_006',
#  'job_desc_007',
#  'job_desc_008',
#  'job_desc_009',
#  'job_desc_010',
#  'job_desc_011',
#  'job_desc_012',
#  'job_desc_013',
#  'job_desc_014',
#  'job_desc_015',
#  'job_desc_016',
#  'job_desc_017',
#  'job_desc_018',
#  'job_desc_019',
#  'job_desc_020',
#  'job_desc_021',
#  'job_desc_022',
#  'job_desc_023',
#  'job_desc_024',
#  'job_desc_025',
#  'job_desc_026',
#  'job_desc_027',
#  'job_desc_028',
#  'job_desc_029',
#  'job_desc_030',
#  'job_desc_031',
#  'job_desc_032',
#  'job_desc_033',
#  'job_desc_034',
#  'job_desc_035',
#  'job_desc_036',
#  'job_desc_037',
#  'job_desc_038',
#  'job_desc_039',
#  'job_desc_040',
#  'job_desc_041',
#  'job_desc_042',
#  'job_desc_043',
#  'job_desc_044',
#  'job_desc_045',
#  'job_desc_046',
#  'job_desc_047',
#  'job_desc_048',
#  'job_desc_049',
#  'job_desc_050',
#  'job_desc_051',
#  'job_desc_052',
#  'job_desc_053',
#  'job_desc_054',
#  'job_desc_055',
#  'job_desc_056',
#  'job_desc_057',
#  'job_desc_058',
#  'job_desc_059',
#  'job_desc_060',
#  'job_desc_061',
#  'job_desc_062',
#  'job_desc_063',
#  'job_desc_064',
#  'job_desc_065',
#  'job_desc_066',
#  'job_desc_067',
#  'job_desc_068',
#  'job_desc_069',
#  'job_desc_070',
#  'job_desc_071',
#  'job_desc_072',
#  'job_desc_073',
#  'job_desc_074',
#  'job_desc_075',
#  'job_desc_076',
#  'job_desc_077',
#  'job_desc_078',
#  'job_desc_079',
#  'job_desc_080',
#  'job_desc_081',
#  'job_desc_082',
#  'job_desc_083',
#  'job_desc_084',
#  'job_desc_085',
#  'job_desc_086',
#  'job_desc_087',
#  'job_desc_088',
#  'job_desc_089',
#  'job_desc_090',
#  'job_desc_091',
#  'job_desc_092',
#  'job_desc_093',
#  'job_desc_094',
#  'job_desc_095',
#  'job_desc_096',
#  'job_desc_097',
#  'job_desc_098',
#  'job_desc_099',
#  'job_desc_100',
#  'job_desc_101',
#  'job_desc_102',
#  'job_desc_103',
#  'job_desc_104',
#  'job_desc_105',
#  'job_desc_106',
#  'job_desc_107',
#  'job_desc_108',
#  'job_desc_109',
#  'job_desc_110',
#  'job_desc_111',
#  'job_desc_112',
#  'job_desc_113',
#  'job_desc_114',
#  'job_desc_115',
#  'job_desc_116',
#  'job_desc_117',
#  'job_desc_118',
#  'job_desc_119',
#  'job_desc_120',
#  'job_desc_121',
#  'job_desc_122',
#  'job_desc_123',
#  'job_desc_124',
#  'job_desc_125',
#  'job_desc_126',
#  'job_desc_127',
#  'job_desc_128',
#  'job_desc_129',
#  'job_desc_130',
#  'job_desc_131',
#  'job_desc_132',
#  'job_desc_133',
#  'job_desc_134',
#  'job_desc_135',
#  'job_desc_136',
#  'job_desc_137',
#  'job_desc_138',
#  'job_desc_139',
#  'job_desc_140',
#  'job_desc_141',
#  'job_desc_142',
#  'job_desc_143',
#  'job_desc_144',
#  'job_desc_145',
#  'job_desc_146',
#  'job_desc_147',
#  'job_desc_148',
#  'job_desc_149',
#  'job_desc_150',
#  'job_desc_151',
#  'job_desc_152',
#  'job_desc_153',
#  'job_desc_154',
#  'job_desc_155',
#  'job_desc_156',
#  'job_desc_157',
#  'job_desc_158',
#  'job_desc_159',
#  'job_desc_160',
#  'job_desc_161',
#  'job_desc_162',
#  'job_desc_163',
#  'job_desc_164',
#  'job_desc_165',
#  'job_desc_166',
#  'job_desc_167',
#  'job_desc_168',
#  'job_desc_169',
#  'job_desc_170',
#  'job_desc_171',
#  'job_desc_172',
#  'job_desc_173',
#  'job_desc_174',
#  'job_desc_175',
#  'job_desc_176',
#  'job_desc_177',
#  'job_desc_178',
#  'job_desc_179',
#  'job_desc_180',
#  'job_desc_181',
#  'job_desc_182',
#  'job_desc_183',
#  'job_desc_184',
#  'job_desc_185',
#  'job_desc_186',
#  'job_desc_187',
#  'job_desc_188',
#  'job_desc_189',
#  'job_desc_190',
#  'job_desc_191',
#  'job_desc_192',
#  'job_desc_193',
#  'job_desc_194',
#  'job_desc_195',
#  'job_desc_196',
#  'job_desc_197',
#  'job_desc_198',
#  'job_desc_199',
#  'job_desc_200',
#  'job_desc_201',
#  'job_desc_202',
#  'job_desc_203',
#  'job_desc_204',
#  'job_desc_205',
#  'job_desc_206',
#  'job_desc_207',
#  'job_desc_208',
#  'job_desc_209',
#  'job_desc_210',
#  'job_desc_211',
#  'job_desc_212',
#  'job_desc_213',
#  'job_desc_214',
#  'job_desc_215',
#  'job_desc_216',
#  'job_desc_217',
#  'job_desc_218',
#  'job_desc_219',
#  'job_desc_220',
#  'job_desc_221',
#  'job_desc_222',
#  'job_desc_223',
#  'job_desc_224',
#  'job_desc_225',
#  'job_desc_226',
#  'job_desc_227',
#  'job_desc_228',
#  'job_desc_229',
#  'job_desc_230',
#  'job_desc_231',
#  'job_desc_232',
#  'job_desc_233',
#  'job_desc_234',
#  'job_desc_235',
#  'job_desc_236',
#  'job_desc_237',
#  'job_desc_238',
#  'job_desc_239',
#  'job_desc_240',
#  'job_desc_241',
#  'job_desc_242',
#  'job_desc_243',
#  'job_desc_244',
#  'job_desc_245',
#  'job_desc_246',
#  'job_desc_247',
#  'job_desc_248',
#  'job_desc_249',
#  'job_desc_250',
#  'job_desc_251',
#  'job_desc_252',
#  'job_desc_253',
#  'job_desc_254',
#  'job_desc_255',
#  'job_desc_256',
#  'job_desc_257',
#  'job_desc_258',
#  'job_desc_259',
#  'job_desc_260',
#  'job_desc_261',
#  'job_desc_262',
#  'job_desc_263',
#  'job_desc_264',
#  'job_desc_265',
#  'job_desc_266',
#  'job_desc_267',
#  'job_desc_268',
#  'job_desc_269',
#  'job_desc_270',
#  'job_desc_271',
#  'job_desc_272',
#  'job_desc_273',
#  'job_desc_274',
#  'job_desc_275',
#  'job_desc_276',
#  'job_desc_277',
#  'job_desc_278',
#  'job_desc_279',
#  'job_desc_280',
#  'job_desc_281',
#  'job_desc_282',
#  'job_desc_283',
#  'job_desc_284',
#  'job_desc_285',
#  'job_desc_286',
#  'job_desc_287',
#  'job_desc_288',
#  'job_desc_289',
#  'job_desc_290',
#  'job_desc_291',
#  'job_desc_292',
#  'job_desc_293',
#  'job_desc_294',
#  'job_desc_295',
#  'job_desc_296',
#  'job_desc_297',
#  'job_desc_298',
#  'job_desc_299',
#  'job_desc_300']

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1280 entries, 0 to 1279
# Columns: 317 entries, obs to job_desc_300
# dtypes: bool(9), float64(302), int64(1), object(5)
# memory usage: 3.0+ MB

# %%
train_df.describe()
# Out:
#                obs    feature_2  feature_10  job_desc_001  job_desc_002  \
# count  1280.000000  1280.000000  834.000000   1280.000000   1280.000000
# mean    640.500000     0.592414   57.388489      0.195011      1.775129
# std     369.648482     0.108669   31.695205      0.223345      0.786083
# min       1.000000     0.377300    6.000000     -0.763939      0.000000
# 25%     320.750000     0.470400   36.000000      0.000000      1.644593
# 50%     640.500000     0.599500   60.000000      0.199483      1.965052
# 75%     960.250000     0.685425   60.000000      0.362435      2.236504
# max    1280.000000     0.906300  300.000000      0.871714      3.954989
#
#        job_desc_003  job_desc_004  job_desc_005  job_desc_006  job_desc_007  \
# count   1280.000000   1280.000000   1280.000000   1280.000000   1280.000000
# mean      -0.471561     -0.106538     -0.056146     -0.283087     -0.489879
# std        0.291197      0.291319      0.145954      0.196887      0.263636
# min       -2.138069     -1.699230     -0.720396     -0.814064     -1.426136
# 25%       -0.650494     -0.266094     -0.140586     -0.428859     -0.652866
# 50%       -0.511752     -0.041913     -0.034192     -0.300990     -0.512744
# 75%       -0.316367      0.043819      0.022705     -0.134271     -0.362571
# max        1.223969      1.065928      0.596698      0.384203      0.138056
#
#        ...  job_desc_291  job_desc_292  job_desc_293  job_desc_294  \
# count  ...   1280.000000   1280.000000   1280.000000   1280.000000
# mean   ...     -0.229636     -0.504288     -0.337300     -0.205454
# std    ...      0.230086      0.297868      0.243932      0.243926
# min    ...     -1.139693     -1.553501     -1.308425     -1.056830
# 25%    ...     -0.381261     -0.694498     -0.503943     -0.367195
# 50%    ...     -0.218812     -0.527023     -0.363801     -0.193773
# 75%    ...     -0.044063     -0.334472     -0.154570      0.000000
# max    ...      0.800289      0.429345      0.501037      0.741466
#
#        job_desc_295  job_desc_296  job_desc_297  job_desc_298  job_desc_299  \
# count   1280.000000   1280.000000   1280.000000   1280.000000   1280.000000
# mean       0.062491     -0.289679     -0.125236     -0.609413     -0.697959
# std        0.142622      0.194618      0.160217      0.280257      0.333347
# min       -0.682076     -1.044931     -1.427914     -1.273351     -1.448333
# 25%       -0.000332     -0.416289     -0.220456     -0.779942     -0.913277
# 50%        0.044535     -0.300416     -0.102293     -0.666355     -0.789911
# 75%        0.149352     -0.158362      0.000000     -0.533758     -0.584597
# max        0.858132      0.208166      0.236223      0.000000      0.232129
#
#        job_desc_300
# count   1280.000000
# mean      -0.065607
# std        0.149354
# min       -1.563567
# 25%       -0.155716
# 50%       -0.048348
# 75%        0.008720
# max        0.460499
#
# [8 rows x 303 columns]

# %%
dict(train_df.isnull().sum())
# Out:
# {'obs': 0,
#  'job_title': 0,
#  'job_posted_date': 1,
#  'salary_category': 0,
#  'job_state': 27,
#  'feature_1': 0,
#  'feature_2': 0,
#  'feature_3': 0,
#  'feature_4': 0,
#  'feature_5': 0,
#  'feature_6': 0,
#  'feature_7': 0,
#  'feature_8': 0,
#  'feature_9': 0,
#  'feature_10': 446,
#  'feature_11': 0,
#  'feature_12': 0,
#  'job_desc_001': 0,
#  'job_desc_002': 0,
#  'job_desc_003': 0,
#  'job_desc_004': 0,
#  'job_desc_005': 0,
#  'job_desc_006': 0,
#  'job_desc_007': 0,
#  'job_desc_008': 0,
#  'job_desc_009': 0,
#  'job_desc_010': 0,
#  'job_desc_011': 0,
#  'job_desc_012': 0,
#  'job_desc_013': 0,
#  'job_desc_014': 0,
#  'job_desc_015': 0,
#  'job_desc_016': 0,
#  'job_desc_017': 0,
#  'job_desc_018': 0,
#  'job_desc_019': 0,
#  'job_desc_020': 0,
#  'job_desc_021': 0,
#  'job_desc_022': 0,
#  'job_desc_023': 0,
#  'job_desc_024': 0,
#  'job_desc_025': 0,
#  'job_desc_026': 0,
#  'job_desc_027': 0,
#  'job_desc_028': 0,
#  'job_desc_029': 0,
#  'job_desc_030': 0,
#  'job_desc_031': 0,
#  'job_desc_032': 0,
#  'job_desc_033': 0,
#  'job_desc_034': 0,
#  'job_desc_035': 0,
#  'job_desc_036': 0,
#  'job_desc_037': 0,
#  'job_desc_038': 0,
#  'job_desc_039': 0,
#  'job_desc_040': 0,
#  'job_desc_041': 0,
#  'job_desc_042': 0,
#  'job_desc_043': 0,
#  'job_desc_044': 0,
#  'job_desc_045': 0,
#  'job_desc_046': 0,
#  'job_desc_047': 0,
#  'job_desc_048': 0,
#  'job_desc_049': 0,
#  'job_desc_050': 0,
#  'job_desc_051': 0,
#  'job_desc_052': 0,
#  'job_desc_053': 0,
#  'job_desc_054': 0,
#  'job_desc_055': 0,
#  'job_desc_056': 0,
#  'job_desc_057': 0,
#  'job_desc_058': 0,
#  'job_desc_059': 0,
#  'job_desc_060': 0,
#  'job_desc_061': 0,
#  'job_desc_062': 0,
#  'job_desc_063': 0,
#  'job_desc_064': 0,
#  'job_desc_065': 0,
#  'job_desc_066': 0,
#  'job_desc_067': 0,
#  'job_desc_068': 0,
#  'job_desc_069': 0,
#  'job_desc_070': 0,
#  'job_desc_071': 0,
#  'job_desc_072': 0,
#  'job_desc_073': 0,
#  'job_desc_074': 0,
#  'job_desc_075': 0,
#  'job_desc_076': 0,
#  'job_desc_077': 0,
#  'job_desc_078': 0,
#  'job_desc_079': 0,
#  'job_desc_080': 0,
#  'job_desc_081': 0,
#  'job_desc_082': 0,
#  'job_desc_083': 0,
#  'job_desc_084': 0,
#  'job_desc_085': 0,
#  'job_desc_086': 0,
#  'job_desc_087': 0,
#  'job_desc_088': 0,
#  'job_desc_089': 0,
#  'job_desc_090': 0,
#  'job_desc_091': 0,
#  'job_desc_092': 0,
#  'job_desc_093': 0,
#  'job_desc_094': 0,
#  'job_desc_095': 0,
#  'job_desc_096': 0,
#  'job_desc_097': 0,
#  'job_desc_098': 0,
#  'job_desc_099': 0,
#  'job_desc_100': 0,
#  'job_desc_101': 0,
#  'job_desc_102': 0,
#  'job_desc_103': 0,
#  'job_desc_104': 0,
#  'job_desc_105': 0,
#  'job_desc_106': 0,
#  'job_desc_107': 0,
#  'job_desc_108': 0,
#  'job_desc_109': 0,
#  'job_desc_110': 0,
#  'job_desc_111': 0,
#  'job_desc_112': 0,
#  'job_desc_113': 0,
#  'job_desc_114': 0,
#  'job_desc_115': 0,
#  'job_desc_116': 0,
#  'job_desc_117': 0,
#  'job_desc_118': 0,
#  'job_desc_119': 0,
#  'job_desc_120': 0,
#  'job_desc_121': 0,
#  'job_desc_122': 0,
#  'job_desc_123': 0,
#  'job_desc_124': 0,
#  'job_desc_125': 0,
#  'job_desc_126': 0,
#  'job_desc_127': 0,
#  'job_desc_128': 0,
#  'job_desc_129': 0,
#  'job_desc_130': 0,
#  'job_desc_131': 0,
#  'job_desc_132': 0,
#  'job_desc_133': 0,
#  'job_desc_134': 0,
#  'job_desc_135': 0,
#  'job_desc_136': 0,
#  'job_desc_137': 0,
#  'job_desc_138': 0,
#  'job_desc_139': 0,
#  'job_desc_140': 0,
#  'job_desc_141': 0,
#  'job_desc_142': 0,
#  'job_desc_143': 0,
#  'job_desc_144': 0,
#  'job_desc_145': 0,
#  'job_desc_146': 0,
#  'job_desc_147': 0,
#  'job_desc_148': 0,
#  'job_desc_149': 0,
#  'job_desc_150': 0,
#  'job_desc_151': 0,
#  'job_desc_152': 0,
#  'job_desc_153': 0,
#  'job_desc_154': 0,
#  'job_desc_155': 0,
#  'job_desc_156': 0,
#  'job_desc_157': 0,
#  'job_desc_158': 0,
#  'job_desc_159': 0,
#  'job_desc_160': 0,
#  'job_desc_161': 0,
#  'job_desc_162': 0,
#  'job_desc_163': 0,
#  'job_desc_164': 0,
#  'job_desc_165': 0,
#  'job_desc_166': 0,
#  'job_desc_167': 0,
#  'job_desc_168': 0,
#  'job_desc_169': 0,
#  'job_desc_170': 0,
#  'job_desc_171': 0,
#  'job_desc_172': 0,
#  'job_desc_173': 0,
#  'job_desc_174': 0,
#  'job_desc_175': 0,
#  'job_desc_176': 0,
#  'job_desc_177': 0,
#  'job_desc_178': 0,
#  'job_desc_179': 0,
#  'job_desc_180': 0,
#  'job_desc_181': 0,
#  'job_desc_182': 0,
#  'job_desc_183': 0,
#  'job_desc_184': 0,
#  'job_desc_185': 0,
#  'job_desc_186': 0,
#  'job_desc_187': 0,
#  'job_desc_188': 0,
#  'job_desc_189': 0,
#  'job_desc_190': 0,
#  'job_desc_191': 0,
#  'job_desc_192': 0,
#  'job_desc_193': 0,
#  'job_desc_194': 0,
#  'job_desc_195': 0,
#  'job_desc_196': 0,
#  'job_desc_197': 0,
#  'job_desc_198': 0,
#  'job_desc_199': 0,
#  'job_desc_200': 0,
#  'job_desc_201': 0,
#  'job_desc_202': 0,
#  'job_desc_203': 0,
#  'job_desc_204': 0,
#  'job_desc_205': 0,
#  'job_desc_206': 0,
#  'job_desc_207': 0,
#  'job_desc_208': 0,
#  'job_desc_209': 0,
#  'job_desc_210': 0,
#  'job_desc_211': 0,
#  'job_desc_212': 0,
#  'job_desc_213': 0,
#  'job_desc_214': 0,
#  'job_desc_215': 0,
#  'job_desc_216': 0,
#  'job_desc_217': 0,
#  'job_desc_218': 0,
#  'job_desc_219': 0,
#  'job_desc_220': 0,
#  'job_desc_221': 0,
#  'job_desc_222': 0,
#  'job_desc_223': 0,
#  'job_desc_224': 0,
#  'job_desc_225': 0,
#  'job_desc_226': 0,
#  'job_desc_227': 0,
#  'job_desc_228': 0,
#  'job_desc_229': 0,
#  'job_desc_230': 0,
#  'job_desc_231': 0,
#  'job_desc_232': 0,
#  'job_desc_233': 0,
#  'job_desc_234': 0,
#  'job_desc_235': 0,
#  'job_desc_236': 0,
#  'job_desc_237': 0,
#  'job_desc_238': 0,
#  'job_desc_239': 0,
#  'job_desc_240': 0,
#  'job_desc_241': 0,
#  'job_desc_242': 0,
#  'job_desc_243': 0,
#  'job_desc_244': 0,
#  'job_desc_245': 0,
#  'job_desc_246': 0,
#  'job_desc_247': 0,
#  'job_desc_248': 0,
#  'job_desc_249': 0,
#  'job_desc_250': 0,
#  'job_desc_251': 0,
#  'job_desc_252': 0,
#  'job_desc_253': 0,
#  'job_desc_254': 0,
#  'job_desc_255': 0,
#  'job_desc_256': 0,
#  'job_desc_257': 0,
#  'job_desc_258': 0,
#  'job_desc_259': 0,
#  'job_desc_260': 0,
#  'job_desc_261': 0,
#  'job_desc_262': 0,
#  'job_desc_263': 0,
#  'job_desc_264': 0,
#  'job_desc_265': 0,
#  'job_desc_266': 0,
#  'job_desc_267': 0,
#  'job_desc_268': 0,
#  'job_desc_269': 0,
#  'job_desc_270': 0,
#  'job_desc_271': 0,
#  'job_desc_272': 0,
#  'job_desc_273': 0,
#  'job_desc_274': 0,
#  'job_desc_275': 0,
#  'job_desc_276': 0,
#  'job_desc_277': 0,
#  'job_desc_278': 0,
#  'job_desc_279': 0,
#  'job_desc_280': 0,
#  'job_desc_281': 0,
#  'job_desc_282': 0,
#  'job_desc_283': 0,
#  'job_desc_284': 0,
#  'job_desc_285': 0,
#  'job_desc_286': 0,
#  'job_desc_287': 0,
#  'job_desc_288': 0,
#  'job_desc_289': 0,
#  'job_desc_290': 0,
#  'job_desc_291': 0,
#  'job_desc_292': 0,
#  'job_desc_293': 0,
#  'job_desc_294': 0,
#  'job_desc_295': 0,
#  'job_desc_296': 0,
#  'job_desc_297': 0,
#  'job_desc_298': 0,
#  'job_desc_299': 0,
#  'job_desc_300': 0}
